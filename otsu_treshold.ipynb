# %% [markdown]
# <a href="https://colab.research.google.com/github/Fadiasitinursifa/tugas_paper/blob/main/otsu_treshold.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread("/content/sample_data/jeruk.jpg")
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
im1 = img.copy()
ret,im1 = cv2.threshold(im1,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# %%
plt.figure(1)
plt.subplot(121)
plt.imshow(img,cmap='gray')

# %%
plt.subplot(122)
plt.imshow(im1,cmap='gray')
plt.show()
